# %% [markdown]
# <a href="https://colab.research.google.com/github/gsrinivasa7/IndianStockPredictor/blob/main/Indian_stock_market_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# !pip install scikit-learn
# !pip install matplotlib
# !pip install pandas

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
stock = yf.Ticker("RELIANCE.NS")  # NSE stocks have ".NS" at the end
df = stock.history(period="1y")  # or use period="5d", "1mo", etc.
df.reset_index(inplace=True)
df.tail()
# Out:
#                          Date         Open         High          Low  \
# 245 2025-06-12 00:00:00+05:30  1453.500000  1457.000000  1434.400024
# 246 2025-06-13 00:00:00+05:30  1424.000000  1435.500000  1414.300049
# 247 2025-06-16 00:00:00+05:30  1426.900024  1442.400024  1424.400024
# 248 2025-06-17 00:00:00+05:30  1448.000000  1448.000000  1425.800049
# 249 2025-06-18 00:00:00+05:30  1430.000000  1442.800049  1425.699951
#
#            Close    Volume  Dividends  Stock Splits
# 245  1441.599976   8828114        0.0           0.0
# 246  1427.900024   9757276        0.0           0.0
# 247  1437.800049   8458093        0.0           0.0
# 248  1431.199951  10366599        0.0           0.0
# 249  1427.300049   4618173        0.0           0.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df['Prediction'] = df[['Close']].shift(-1)

X = np.array(df[['Close']])[:-1]
y = np.array(df['Prediction'])[:-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

lr = LinearRegression()
lr.fit(X_train, y_train)

predicted_prices = lr.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(y_test, label="Actual")
plt.plot(predicted_prices, label="Predicted")
plt.legend()
plt.title("Stock Price Prediction")
plt.xlabel("Days")
plt.ylabel("Price")
plt.grid(True)
plt.show()

mse = mean_squared_error(y_test, predicted_prices)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 449.3591654190077
